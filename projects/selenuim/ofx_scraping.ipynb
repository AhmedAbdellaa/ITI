# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import time 
from datetime import datetime
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://www.ofx.com/en-ca/forex-news/historical-exchange-rates/yearly-average-rates/')  
time.sleep(1)
select = driver.find_element_by_class_name("ofx-market-chart__currency__control")
driver.execute_script("arguments[0].scrollIntoView();", select)
time.sleep(2)


all =[]
currs = []
select.click()
values_lengh =len( driver.find_elements_by_xpath('//div[@class="currency-opt-full"]/strong'))
select.click()
for i in range(values_lengh):
    select.click()
    value = driver.find_elements_by_xpath('//div[@class="currency-opt-full"]/strong')
    curr = value[i].text
    print(curr)
    value[i].click()
    time.sleep(1)
    rows = driver.find_elements_by_xpath('//tr/td')[4:]
    print(len(rows))
    print(type(rows))
    currs.extend([curr]*int(len(rows)/2))
    for row in rows :
        
        all.append(row.text)
df = pd.DataFrame({'Currancy':currs,'Date':all[0::2],'Rate':all[1::2]})
print(df.info())
df.head()
df.to_csv(datetime.now().strftime("%Y-%m-%d")+'.csv',index=False)
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_500\1895805319.py:11: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   select = driver.find_element_by_class_name("ofx-market-chart__currency__control")
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_500\1895805319.py:19: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   values_lengh =len( driver.find_elements_by_xpath('//div[@class="currency-opt-full"]/strong'))
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_500\1895805319.py:23: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   value = driver.find_elements_by_xpath('//div[@class="currency-opt-full"]/strong')
# CAD
# ...

# %%
df.head()
# Out:
#   Currancy               Date      Rate
# 0      CAD  December 31, 1990  0.857188
# 1      CAD  December 31, 1991  0.872637
# 2      CAD  December 31, 1992  0.828136
# 3      CAD  December 31, 1993  0.775451
# 4      CAD  December 31, 1994  0.732021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1881 entries, 0 to 1880
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Currancy  1881 non-null   object
#  1   Date      1881 non-null   object
#  2   Rate      1881 non-null   object
# dtypes: object(3)
# memory usage: 44.2+ KB
